# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/AIHEART/blob/main/read_STATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-750efd2f-c9cc-4b11-9635-bc000ba357c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-750efd2f-c9cc-4b11-9635-bc000ba357c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving GIACC Base HDM n_99.dta to GIACC Base HDM n_99.dta

# %%
import pandas as pd
dfs = pd.read_stata('GIACC Base HDM n_99.dta')
dfs.head()
# Out:
#     fechaabl   numeroh  edad  ... ArRel1_5_2 ArRelMay2      filter__
# 0 2015-06-22  326825.0  65.0  ...     0.0380    0.1369      Selected
# 1 2015-07-22  219618.0  79.0  ...     0.0441    0.1433  Not Selected
# 2 2015-07-23  545584.0  67.0  ...     0.0629    0.1766  Not Selected
# 3 2015-07-28  187307.0  75.0  ...     0.0577    0.2984  Not Selected
# 4 2015-08-04  176453.0  82.0  ...     0.0077    0.0021  Not Selected
#
# [5 rows x 163 columns]
